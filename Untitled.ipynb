# %%
f = open('oecd 교통사고.csv')
asia = ['대한민국','일본','터키','이스라엘']
eu = ['그리스', '네덜란드','노르웨이','덴마크', '독일','라트비아', '룩셈부르크', '벨기에', '스웨덴', '스위스', '스페인', '슬로바키아', '슬로베니아', '아이슬란드', '아일랜드','에스토니아',
         '영국', '오스트리아', '이탈리아','체코','포르투갈','폴란드','프랑스','헝가리','핀란드']
na = ['캐나다', '미국', '멕시코']
sa = ['칠레']
oce = ['호주', '뉴질랜드']


asiac=[]
europec = []
norc= []
southc = []
oceac=[]

kimsky = []


data = csv.reader(f)

for row in data:
    if row[0] in asia :
        asiac.append(int(row[2]))
    elif row[0] in eu :
        europec.append(int(row[2]))
    elif row[0] in na :
        norc.append(int(row[2]))
    elif row[0] in sa :
        southc.append(int(row[2]))
    elif row[0] in oce :
        oceac.append(int(row[2]))
kimsky.append(sum(asiac))
kimsky.append(sum(europec))
kimsky.append(sum(norc))
kimsky.append(sum(southc))
kimsky.append(sum(oceac))

print(kimsky)

kimsukgawi = open('OECD사고.csv')

dat = csv.reader(kimsukgawi)


asiacar = []
europecar = []
norcar = []
southcar = []
oceacar = []

sky = []

for row in dat:
    if row[1] in asia :
        asiacar.append(int(1000*float(row[2])))
    
    elif row[1] in eu :
        europecar.append(int(1000*float(row[2])))
    
    elif row[1] in na :
        norcar.append(int(1000*float(row[2])))
    
    elif row[1] in sa :
        southcar.append(int(1000*float(row[2])))
    
    elif row[1] in oce :
        oceacar.append(int(1000*float(row[2])))

sky.append(sum(asiacar))
sky.append(sum(europecar))
sky.append(sum(norcar))
sky.append(sum(southcar))
sky.append(sum(oceacar))

print(sky)

a = 13000000*kimsky[0]/sky[0]
b = 13000000*kimsky[1]/sky[1]
c = 13000000*kimsky[2]/sky[2]
d = 13000000*kimsky[3]/sky[3]
e = 13000000*kimsky[4]/sky[4]

print(a)
print(b)
print(c)
print(d)
print(e)

x = []
y = []
z = []


x.append(250)
x.append(160)
x.append(45)
x.append(80)
x.append(295)
y.append(45)
y.append(50)
y.append(45)
y.append(-37.5)
y.append(-45)
z.append(a)
z.append(b)
z.append(c)
z.append(d)
z.append(e)
    


import csv
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font',family='Malgun Gothic')
from bs4 import BeautifulSoup

img = plt.imread('대륙지도.png')

fig,ax=plt.subplots()
ax.imshow(img, extent = (0,360,-90,90))
plt.title('대륙별 자동차당 교통사고 사망수')
plt.scatter(x, y, s = z, c = ['r','g','m','c','b'], alpha = 1)
plt.show()
# Out:
# [17358, 22728, 40440, 2140, 1524]
# [137102000, 320225000, 339856000, 4263000, 21523000]
# 1645.8840863007104
# 922.6762432664533
# 1546.890447719034
# 6525.920713112831
# 920.5036472610695
